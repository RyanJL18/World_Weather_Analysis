# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime
# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size =1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | nipawin
# Processing Record 4 of Set 1 | tondano
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | key west
# Processing Record 9 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | foggia
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | baglung
# Processing Record 19 of Set 1 | stolbovaya
# Processing Record 20 of Set 1 | kilindoni
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | ushtobe
# Processing Record 23 of Set 1 | mersing
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | aklavik
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 1 | guiberoua
# Processing Record 36 of Set 1 | nouadhibou
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | la chaux-de-fonds
# Processing Record 39 of Set 1 | umm kaddadah
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | borogontsy
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | casa nova
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | krasnoselkup
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | praia da vitoria
# Processing Record 48 of Set 1 | nanortalik
# Processing Record 49 of Set 1 | tomball
# Processing Record 50 of Set 1 | zarinsk
# Processing Record 1 of Set 2 | ixtapa
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | port-gentil
# Processing Record 5 of Set 2 | lima
# Processing Record 6 of Set 2 | davila
# Processing Record 7 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 2 | neiafu
# Processing Record 9 of Set 2 | tuatapere
# Processing Record 10 of Set 2 | boyolangu
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | svetlogorsk
# Processing Record 18 of Set 2 | verkhniy rohachyk
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | yulara
# Processing Record 22 of Set 2 | hirara
# Processing Record 23 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | college
# Processing Record 26 of Set 2 | zacualpan
# Processing Record 27 of Set 2 | port lincoln
# Processing Record 28 of Set 2 | nueve de julio
# Processing Record 29 of Set 2 | norman wells
# Processing Record 30 of Set 2 | lazaro cardenas
# Processing Record 31 of Set 2 | flinders
# Processing Record 32 of Set 2 | ouallam
# Processing Record 33 of Set 2 | toccoa
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | mushie
# Processing Record 36 of Set 2 | high level
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | cayenne
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | sandakan
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | acarau
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | marana
# Processing Record 45 of Set 2 | imphal
# Processing Record 46 of Set 2 | ilulissat
# Processing Record 47 of Set 2 | sandur
# Processing Record 48 of Set 2 | hofn
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | zyryanka
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | guerrero negro
# Processing Record 6 of Set 3 | aykhal
# Processing Record 7 of Set 3 | karlsfeld
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | chihuahua
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | platteville
# Processing Record 14 of Set 3 | ust-kuyga
# Processing Record 15 of Set 3 | taltal
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | palau
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | we
# City not found. Skipping...
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | den helder
# Processing Record 24 of Set 3 | fortuna
# Processing Record 25 of Set 3 | nikolskoye
# Processing Record 26 of Set 3 | sao joao do paraiso
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | butaritari
# Processing Record 30 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | zachagansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | marawi
# Processing Record 34 of Set 3 | herat
# Processing Record 35 of Set 3 | mindelo
# Processing Record 36 of Set 3 | roald
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | isiro
# Processing Record 40 of Set 3 | kuching
# Processing Record 41 of Set 3 | alta floresta
# Processing Record 42 of Set 3 | phan thiet
# Processing Record 43 of Set 3 | yushan
# Processing Record 44 of Set 3 | hashtrud
# Processing Record 45 of Set 3 | pedra
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | serov
# Processing Record 48 of Set 3 | tuktoyaktuk
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | pisco
# Processing Record 1 of Set 4 | arlit
# Processing Record 2 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | selizharovo
# Processing Record 6 of Set 4 | vostok
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | vao
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | barranca
# Processing Record 11 of Set 4 | swan hill
# Processing Record 12 of Set 4 | kizukuri
# Processing Record 13 of Set 4 | nemuro
# Processing Record 14 of Set 4 | gao
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | carballo
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 4 | gizo
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | vestmanna
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | camocim
# Processing Record 24 of Set 4 | gunnedah
# Processing Record 25 of Set 4 | magnitka
# Processing Record 26 of Set 4 | urengoy
# Processing Record 27 of Set 4 | tazovskiy
# Processing Record 28 of Set 4 | huazolotitlan
# City not found. Skipping...
# Processing Record 29 of Set 4 | marathon
# Processing Record 30 of Set 4 | ibra
# Processing Record 31 of Set 4 | fort saint james
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 4 | champasak
# Processing Record 35 of Set 4 | saint-joseph
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | port hawkesbury
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | ancud
# Processing Record 40 of Set 4 | nizhniy tsasuchey
# Processing Record 41 of Set 4 | luderitz
# Processing Record 42 of Set 4 | byron bay
# Processing Record 43 of Set 4 | kadoma
# Processing Record 44 of Set 4 | vilhena
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 4 | villa bruzual
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | tommot
# Processing Record 1 of Set 5 | ambon
# Processing Record 2 of Set 5 | lasem
# Processing Record 3 of Set 5 | katsuura
# Processing Record 4 of Set 5 | kashi
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | banepa
# Processing Record 7 of Set 5 | jumla
# Processing Record 8 of Set 5 | hambantota
# Processing Record 9 of Set 5 | palmer
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | mino
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | talah
# City not found. Skipping...
# Processing Record 14 of Set 5 | narasannapeta
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | rodbyhavn
# Processing Record 18 of Set 5 | ginda
# Processing Record 19 of Set 5 | challans
# Processing Record 20 of Set 5 | udalguri
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | kyra
# Processing Record 23 of Set 5 | guaruja
# Processing Record 24 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 5 | agva
# City not found. Skipping...
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | batsfjord
# Processing Record 28 of Set 5 | elko
# Processing Record 29 of Set 5 | la rioja
# Processing Record 30 of Set 5 | hami
# Processing Record 31 of Set 5 | dubbo
# Processing Record 32 of Set 5 | espanola
# Processing Record 33 of Set 5 | torbay
# Processing Record 34 of Set 5 | chapais
# Processing Record 35 of Set 5 | vanavara
# Processing Record 36 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 5 | grindavik
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | ostrovnoy
# Processing Record 40 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 5 | maarianhamina
# Processing Record 42 of Set 5 | ugoofaaru
# Processing Record 43 of Set 5 | chagoda
# Processing Record 44 of Set 5 | srednekolymsk
# Processing Record 45 of Set 5 | dikson
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | provideniya
# Processing Record 49 of Set 5 | bonanza
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | tiznit
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | new waterford
# Processing Record 4 of Set 6 | te anau
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | marsa matruh
# Processing Record 7 of Set 6 | moerai
# Processing Record 8 of Set 6 | xinzhi
# Processing Record 9 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 6 | correntina
# Processing Record 11 of Set 6 | kodinsk
# Processing Record 12 of Set 6 | upington
# Processing Record 13 of Set 6 | umm lajj
# Processing Record 14 of Set 6 | oistins
# Processing Record 15 of Set 6 | cooma
# Processing Record 16 of Set 6 | bathsheba
# Processing Record 17 of Set 6 | gawler
# Processing Record 18 of Set 6 | lang son
# Processing Record 19 of Set 6 | sfantu gheorghe
# Processing Record 20 of Set 6 | kasongo-lunda
# Processing Record 21 of Set 6 | dabakala
# Processing Record 22 of Set 6 | tupik
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | gwanda
# Processing Record 25 of Set 6 | milkovo
# Processing Record 26 of Set 6 | tokur
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | brazzaville
# Processing Record 31 of Set 6 | codrington
# Processing Record 32 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 33 of Set 6 | marzuq
# Processing Record 34 of Set 6 | rabo de peixe
# Processing Record 35 of Set 6 | lumeje
# Processing Record 36 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 6 | phangnga
# Processing Record 38 of Set 6 | sinnamary
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 6 | vila franca do campo
# Processing Record 42 of Set 6 | montefiascone
# Processing Record 43 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | uyemskiy
# Processing Record 46 of Set 6 | bereda
# Processing Record 47 of Set 6 | tazmalt
# Processing Record 48 of Set 6 | lompoc
# Processing Record 49 of Set 6 | pierre
# Processing Record 50 of Set 6 | portland
# Processing Record 1 of Set 7 | san quintin
# Processing Record 2 of Set 7 | morant bay
# Processing Record 3 of Set 7 | ust-tsilma
# Processing Record 4 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 7 | kirakira
# Processing Record 6 of Set 7 | wawa
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | acapulco
# Processing Record 9 of Set 7 | thompson
# Processing Record 10 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 7 | dunedin
# Processing Record 12 of Set 7 | rosario
# Processing Record 13 of Set 7 | gigmoto
# Processing Record 14 of Set 7 | pringsewu
# Processing Record 15 of Set 7 | road town
# Processing Record 16 of Set 7 | tura
# Processing Record 17 of Set 7 | ambatolampy
# Processing Record 18 of Set 7 | itarema
# Processing Record 19 of Set 7 | kasempa
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | visnes
# Processing Record 22 of Set 7 | kaduna
# Processing Record 23 of Set 7 | gornyy
# Processing Record 24 of Set 7 | zhangye
# Processing Record 25 of Set 7 | prainha
# Processing Record 26 of Set 7 | kupang
# Processing Record 27 of Set 7 | rio gallegos
# Processing Record 28 of Set 7 | karpathos
# Processing Record 29 of Set 7 | bandarbeyla
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | chifeng
# Processing Record 32 of Set 7 | bundaberg
# Processing Record 33 of Set 7 | trofors
# Processing Record 34 of Set 7 | narsaq
# Processing Record 35 of Set 7 | jamame
# Processing Record 36 of Set 7 | cutzamala
# City not found. Skipping...
# Processing Record 37 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 7 | cockburn town
# Processing Record 40 of Set 7 | matagami
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | galesong
# Processing Record 43 of Set 7 | saint-georges
# Processing Record 44 of Set 7 | boda
# Processing Record 45 of Set 7 | maceio
# Processing Record 46 of Set 7 | hazaribag
# Processing Record 47 of Set 7 | sangmelima
# Processing Record 48 of Set 7 | libenge
# Processing Record 49 of Set 7 | bambanglipuro
# Processing Record 50 of Set 7 | cabimas
# Processing Record 1 of Set 8 | naze
# Processing Record 2 of Set 8 | asau
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 8 | tecpan
# Processing Record 6 of Set 8 | elmira
# Processing Record 7 of Set 8 | mazatlan
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | oksfjord
# Processing Record 10 of Set 8 | seinajoki
# Processing Record 11 of Set 8 | longyearbyen
# Processing Record 12 of Set 8 | ambilobe
# Processing Record 13 of Set 8 | homer
# Processing Record 14 of Set 8 | koulamoutou
# Processing Record 15 of Set 8 | dingli
# Processing Record 16 of Set 8 | urusha
# Processing Record 17 of Set 8 | klaksvik
# Processing Record 18 of Set 8 | poum
# Processing Record 19 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 8 | svetlyy
# Processing Record 21 of Set 8 | eregli
# Processing Record 22 of Set 8 | abu samrah
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | terme
# Processing Record 25 of Set 8 | hanzhong
# Processing Record 26 of Set 8 | batagay-alyta
# Processing Record 27 of Set 8 | polunochnoye
# Processing Record 28 of Set 8 | sakskobing
# Processing Record 29 of Set 8 | esik
# Processing Record 30 of Set 8 | bam
# Processing Record 31 of Set 8 | labuhan
# Processing Record 32 of Set 8 | saldanha
# Processing Record 33 of Set 8 | taseyevo
# Processing Record 34 of Set 8 | nyanza
# Processing Record 35 of Set 8 | isnos
# Processing Record 36 of Set 8 | strezhevoy
# Processing Record 37 of Set 8 | ust-nera
# Processing Record 38 of Set 8 | hualmay
# Processing Record 39 of Set 8 | yarensk
# Processing Record 40 of Set 8 | ola
# Processing Record 41 of Set 8 | pasaje
# Processing Record 42 of Set 8 | mirabad
# Processing Record 43 of Set 8 | lata
# Processing Record 44 of Set 8 | cravo norte
# Processing Record 45 of Set 8 | odzaci
# Processing Record 46 of Set 8 | viedma
# Processing Record 47 of Set 8 | ilo
# Processing Record 48 of Set 8 | rajauri
# Processing Record 49 of Set 8 | mayahi
# Processing Record 50 of Set 8 | anaconda
# Processing Record 1 of Set 9 | turayf
# Processing Record 2 of Set 9 | kangaatsiaq
# Processing Record 3 of Set 9 | sur
# Processing Record 4 of Set 9 | soure
# Processing Record 5 of Set 9 | bwanga
# Processing Record 6 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 9 | gombong
# Processing Record 8 of Set 9 | auki
# Processing Record 9 of Set 9 | manakara
# Processing Record 10 of Set 9 | minot
# Processing Record 11 of Set 9 | loanda
# Processing Record 12 of Set 9 | severo-kurilsk
# Processing Record 13 of Set 9 | kaeo
# Processing Record 14 of Set 9 | mumbwa
# Processing Record 15 of Set 9 | laguna
# Processing Record 16 of Set 9 | necochea
# Processing Record 17 of Set 9 | mocuba
# Processing Record 18 of Set 9 | chiredzi
# Processing Record 19 of Set 9 | dondo
# Processing Record 20 of Set 9 | meulaboh
# Processing Record 21 of Set 9 | la palma
# Processing Record 22 of Set 9 | morondava
# Processing Record 23 of Set 9 | broken hill
# Processing Record 24 of Set 9 | florianopolis
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | awjilah
# Processing Record 27 of Set 9 | the valley
# Processing Record 28 of Set 9 | lebu
# Processing Record 29 of Set 9 | erzurum
# Processing Record 30 of Set 9 | san vicente
# Processing Record 31 of Set 9 | shimoda
# Processing Record 32 of Set 9 | victoria
# Processing Record 33 of Set 9 | duz
# City not found. Skipping...
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | valdivia
# Processing Record 36 of Set 9 | sorong
# Processing Record 37 of Set 9 | bethanien
# Processing Record 38 of Set 9 | da lat
# Processing Record 39 of Set 9 | mariel
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | kropotkin
# Processing Record 42 of Set 9 | rocha
# Processing Record 43 of Set 9 | pacific grove
# Processing Record 44 of Set 9 | sabha
# Processing Record 45 of Set 9 | alamogordo
# Processing Record 46 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 9 | tongliao
# Processing Record 48 of Set 9 | mithimna
# City not found. Skipping...
# Processing Record 49 of Set 9 | dzerzhinsk
# Processing Record 50 of Set 9 | aba
# Processing Record 1 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 2 of Set 10 | qaqortoq
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | vila do maio
# Processing Record 5 of Set 10 | puksoozero
# Processing Record 6 of Set 10 | saint anthony
# Processing Record 7 of Set 10 | reconquista
# Processing Record 8 of Set 10 | bardiyah
# Processing Record 9 of Set 10 | show low
# Processing Record 10 of Set 10 | iralaya
# Processing Record 11 of Set 10 | ayr
# Processing Record 12 of Set 10 | ewa beach
# Processing Record 13 of Set 10 | buraydah
# Processing Record 14 of Set 10 | kavieng
# Processing Record 15 of Set 10 | wamba
# Processing Record 16 of Set 10 | adrar
# Processing Record 17 of Set 10 | paracuru
# Processing Record 18 of Set 10 | mapiripan
# Processing Record 19 of Set 10 | koroni
# Processing Record 20 of Set 10 | shelabolikha
# Processing Record 21 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 10 | changde
# Processing Record 24 of Set 10 | mulatupo
# Processing Record 25 of Set 10 | sulat
# Processing Record 26 of Set 10 | tilichiki
# Processing Record 27 of Set 10 | morgan city
# Processing Record 28 of Set 10 | porto santo
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | parana
# Processing Record 31 of Set 10 | ulety
# Processing Record 32 of Set 10 | matay
# Processing Record 33 of Set 10 | coswig
# Processing Record 34 of Set 10 | oltu
# Processing Record 35 of Set 10 | sayat
# Processing Record 36 of Set 10 | bhitarwar
# Processing Record 37 of Set 10 | kondoros
# Processing Record 38 of Set 10 | korem
# Processing Record 39 of Set 10 | santa rosa
# Processing Record 40 of Set 10 | tezu
# Processing Record 41 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | emerald
# Processing Record 44 of Set 10 | namatanai
# Processing Record 45 of Set 10 | iwanai
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | luangwa
# Processing Record 48 of Set 10 | zaraza
# Processing Record 49 of Set 10 | valparaiso
# Processing Record 50 of Set 10 | susaki
# Processing Record 1 of Set 11 | maltahohe
# Processing Record 2 of Set 11 | abu dhabi
# Processing Record 3 of Set 11 | lavrentiya
# Processing Record 4 of Set 11 | pevek
# Processing Record 5 of Set 11 | botwood
# Processing Record 6 of Set 11 | dum duma
# Processing Record 7 of Set 11 | lodja
# Processing Record 8 of Set 11 | egvekinot
# Processing Record 9 of Set 11 | boddam
# Processing Record 10 of Set 11 | shakawe
# Processing Record 11 of Set 11 | kenai
# Processing Record 12 of Set 11 | tanakpur
# Processing Record 13 of Set 11 | mandalgovi
# Processing Record 14 of Set 11 | port pirie
# Processing Record 15 of Set 11 | hellvik
# Processing Record 16 of Set 11 | noumea
# Processing Record 17 of Set 11 | yining
# Processing Record 18 of Set 11 | dvinskoy
# Processing Record 19 of Set 11 | paamiut
# Processing Record 20 of Set 11 | castelo do piaui
# Processing Record 21 of Set 11 | atar
# Processing Record 22 of Set 11 | sazonovo
# Processing Record 23 of Set 11 | blagoyevo
# Processing Record 24 of Set 11 | yuryevets
# Processing Record 25 of Set 11 | illapel
# Processing Record 26 of Set 11 | belaya gora
# Processing Record 27 of Set 11 | vangaindrano
# Processing Record 28 of Set 11 | sao joao da barra
# Processing Record 29 of Set 11 | wilmington
# Processing Record 30 of Set 11 | oranjemund
# Processing Record 31 of Set 11 | slyudyanka
# Processing Record 32 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | fairbanks
# Processing Record 35 of Set 11 | bandundu
# Processing Record 36 of Set 11 | varhaug
# Processing Record 37 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 39 of Set 11 | maniitsoq
# Processing Record 40 of Set 11 | rusape
# Processing Record 41 of Set 11 | dire dawa
# Processing Record 42 of Set 11 | odweyne
# Processing Record 43 of Set 11 | robertsport
# Processing Record 44 of Set 11 | minab
# Processing Record 45 of Set 11 | alihe
# Processing Record 46 of Set 11 | luganville
# Processing Record 47 of Set 11 | edson
# Processing Record 48 of Set 11 | okha
# Processing Record 49 of Set 11 | shenjiamen
# Processing Record 50 of Set 11 | thenzawl
# Processing Record 1 of Set 12 | dhidhdhoo
# Processing Record 2 of Set 12 | pangkalanbuun
# Processing Record 3 of Set 12 | camacha
# Processing Record 4 of Set 12 | goma
# Processing Record 5 of Set 12 | atasu
# Processing Record 6 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 7 of Set 12 | lalibela
# Processing Record 8 of Set 12 | katherine
# Processing Record 9 of Set 12 | kharp
# Processing Record 10 of Set 12 | houma
# Processing Record 11 of Set 12 | sorland
# Processing Record 12 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | kontagora
# Processing Record 14 of Set 12 | jardim
# Processing Record 15 of Set 12 | husavik
# Processing Record 16 of Set 12 | touros
# Processing Record 17 of Set 12 | teya
# Processing Record 18 of Set 12 | les cayes
# Processing Record 19 of Set 12 | salon-de-provence
# Processing Record 20 of Set 12 | cairns
# Processing Record 21 of Set 12 | nadym
# Processing Record 22 of Set 12 | ndele
# Processing Record 23 of Set 12 | orcopampa
# Processing Record 24 of Set 12 | tias
# Processing Record 25 of Set 12 | fort nelson
# Processing Record 26 of Set 12 | ustynivka
# Processing Record 27 of Set 12 | matara
# Processing Record 28 of Set 12 | simbahan
# Processing Record 29 of Set 12 | vestmannaeyjar
# Processing Record 30 of Set 12 | soeng sang
# Processing Record 31 of Set 12 | dembi dolo
# Processing Record 32 of Set 12 | terrace
# Processing Record 33 of Set 12 | nioaque
# Processing Record 34 of Set 12 | astana
# Processing Record 35 of Set 12 | bacolod
# Processing Record 36 of Set 12 | huilong
# Processing Record 37 of Set 12 | doha
# Processing Record 38 of Set 12 | calbuco
# Processing Record 39 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 40 of Set 12 | sola
# Processing Record 41 of Set 12 | solihull
# Processing Record 42 of Set 12 | dillon
# Processing Record 43 of Set 12 | sangar
# Processing Record 44 of Set 12 | taguatinga
# Processing Record 45 of Set 12 | tessalit
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | charlestown
# Processing Record 48 of Set 12 | okitipupa
# Processing Record 49 of Set 12 | mahon
# Processing Record 50 of Set 12 | okato
# Processing Record 1 of Set 13 | namibe
# Processing Record 2 of Set 13 | strathroy
# Processing Record 3 of Set 13 | sisimiut
# Processing Record 4 of Set 13 | kutum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0          Hilo  19.7297 -155.0900     overcast clouds     81.28        80
# 1       Nipawin  53.3668 -104.0009           clear sky     30.24        59
# 2       Tondano   1.3038  124.9112    scattered clouds     78.89        70
# 3       Rikitea -23.1203 -134.9692     overcast clouds     75.70        75
# 4  San Patricio  28.0170  -97.5169     overcast clouds     74.89        90
# 5         Bluff -46.6000  168.3333     overcast clouds     52.81        81
# 6      Key West  24.5557  -81.7826    scattered clouds     82.40        65
# 7    Bredasdorp -34.5322   20.0403           clear sky     52.29        84
# 8     Jamestown  42.0970  -79.2353                mist     55.04        77
# 9  Saint-Pierre -21.3393   55.4781           clear sky     73.90        73
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100        6.91      US  2022-04-26 03:13:46
# 1           0        4.61      CA  2022-04-26 03:15:17
# 2          47        0.67      ID  2022-04-26 03:16:41
# 3          97       16.93      PF  2022-04-26 03:15:46
# 4         100       11.12      US  2022-04-26 03:08:41
# 5         100       25.46      NZ  2022-04-26 03:15:46
# 6          40       17.27      US  2022-04-26 03:16:42
# 7           5        3.56      ZA  2022-04-26 03:15:45
# 8         100       10.36      US  2022-04-26 03:16:42
# 9           0        9.22      RE  2022-04-26 03:16:42

# %%
#Reorder the columns of the data frame
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df.reindex(columns=new_city_data_df)

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US  19.7297 -155.0900     81.28        80         100
# 1       Nipawin      CA  53.3668 -104.0009     30.24        59           0
# 2       Tondano      ID   1.3038  124.9112     78.89        70          47
# 3       Rikitea      PF -23.1203 -134.9692     75.70        75          97
# 4  San Patricio      US  28.0170  -97.5169     74.89        90         100
# 5         Bluff      NZ -46.6000  168.3333     52.81        81         100
# 6      Key West      US  24.5557  -81.7826     82.40        65          40
# 7    Bredasdorp      ZA -34.5322   20.0403     52.29        84           5
# 8     Jamestown      US  42.0970  -79.2353     55.04        77         100
# 9  Saint-Pierre      RE -21.3393   55.4781     73.90        73           0
#
#    Wind Speed Current Description
# 0        6.91     overcast clouds
# 1        4.61           clear sky
# 2        0.67    scattered clouds
# 3       16.93     overcast clouds
# 4       11.12     overcast clouds
# 5       25.46     overcast clouds
# 6       17.27    scattered clouds
# 7        3.56           clear sky
# 8       10.36                mist
# 9        9.22           clear sky

# %%
# Create the output file (CSV).
import os  
os.makedirs('Weather_Database', exist_ok=True)  
# Export the City_Data into a CSV
city_data_df.to_csv('Weather_Database/WeatherPy_Database.csv')
